# %% [markdown]
# # Test `rioda_python_driver`

# %% [markdown]
# ## 1. Setup

# %%
import sys
sys.path.append("../src")

# %%
import rioda_python_driver as riopy

# %% [markdown]
# ## 2. Test generalize functions

# %%
# initialization
uri = 'neo4j://localhost:7687'
userName = 'neo4j'
password = 'neo4j'
driver = riopy.initialize(uri, userName, password)

# %%
# get the name of current knowledge space and collaboration
with driver.session() as session:
    currentKnowledgeSpaceName = session.read_transaction(riopy.get_current_knowledge_space_name).lower()
    currentCollaborationName = session.read_transaction(riopy.get_current_collaboration_name).lower()
print('The Name of Current Knowledge Space is :', currentKnowledgeSpaceName)
print('The Name of Current Collaboration is :', currentCollaborationName)
driver.close()

# %% [markdown]
# ## 3. Test functions for node

# %%
# create an objective
with driver.session() as session:
    objective = riopy.create_objective(
        tx = session,
        currentKnowledgeSpaceName = currentKnowledgeSpaceName,
        currentCollaborationName = currentCollaborationName,
        objectiveName = 'Test Objective',
        status = 'ACTIVE',
        description = 'Test Description',
        priority = 123,
        propertyLabels = ['Test 1', 'Test 2', 'Test 3'],
        point = [1, 2, 3]
    )
print('The identity of the created objective is :', objective)
driver.close()

# %%
# create a potential
with driver.session() as session:
    potential = riopy.create_potential(
        tx = session,
        currentKnowledgeSpaceName = currentKnowledgeSpaceName,
        currentCollaborationName = currentCollaborationName,
        potentialName = 'Test Potential',
        status = 'ACTIVE',
        potentialType = 'Danger',
        description = 'Test Description',
        propertyLabels = ['Test 1', 'Test 2', 'Test 3'],
        point = [1, 2, 3]
    )
print('The identity of the created potential is :', potential)
driver.close()

# %%
# create a potentiality
with driver.session() as session:
    potentiality = riopy.create_potentiality(
        tx = session,
        currentKnowledgeSpaceName = currentKnowledgeSpaceName,
        currentCollaborationName = currentCollaborationName,
        potentialityName = 'Test Potentiality',
        status = 'ACTIVE',
        potentialityType = 'Risk',
        potentialityNature = 'Emerging',
        probability = [0.2, 0.5],
        description = 'Test Description',
        propertyLabels = ['Test 1', 'Test 2', 'Test 3'],
        point = [1, 2, 3]
    )
print('The identity of the created potentiality is :', potentiality)
driver.close()

# %%
# create an actuality
with driver.session() as session:
    actuality = riopy.create_actuality(
        tx = session,
        currentKnowledgeSpaceName = currentKnowledgeSpaceName,
        currentCollaborationName = currentCollaborationName,
        actualityName = 'Test Actuality',
        status = 'ACTIVE',
        actualityType = 'Benefit',
        description = 'Test Description',
        propertyLabels = ['Test 1', 'Test 2', 'Test 3'],
        point = [1, 2, 3]
    )
print('The identity of the created actuality is :', actuality)
driver.close()

# %%
# create a person
with driver.session() as session:
    person = riopy.create_person(
        tx = session,
        currentKnowledgeSpaceName = currentKnowledgeSpaceName,
        currentCollaborationName = currentCollaborationName,
        personName = 'Test Person',
        status = 'ACTIVE',
        description = 'Test Description',
        propertyLabels = ['Test 1', 'Test 2', 'Test 3'],
        point = [1, 2, 3]
    )
print('The identity of the created person is :', person)
driver.close()

# %%
# create a good
with driver.session() as session:
    good = riopy.create_good(
        tx = session,
        currentKnowledgeSpaceName = currentKnowledgeSpaceName,
        currentCollaborationName = currentCollaborationName,
        goodName = 'Test Good',
        status = 'ACTIVE',
        description = 'Test Description',
        propertyLabels = ['Test 1', 'Test 2', 'Test 3'],
        point = [1, 2, 3]
    )
print('The identity of the created good is :', good)
driver.close()

# %%
# create a territory
with driver.session() as session:
    territory = riopy.create_territory(
        tx = session,
        currentKnowledgeSpaceName = currentKnowledgeSpaceName,
        currentCollaborationName = currentCollaborationName,
        territoryName = 'Test Territory',
        status = 'ACTIVE',
        description = 'Test Description',
        propertyLabels = ['Test 1', 'Test 2', 'Test 3']
    )
print('The identity of the created territory is :', territory)
driver.close()

# %%
# create a community
with driver.session() as session:
    community = riopy.create_community(
        tx = session,
        currentKnowledgeSpaceName = currentKnowledgeSpaceName,
        currentCollaborationName = currentCollaborationName,
        communityName = 'Test Community',
        status = 'ACTIVE',
        description = 'Test Description',
        propertyLabels = ['Test 1', 'Test 2', 'Test 3'],
        point = [1, 2, 3]
    )
print('The identity of the created community is :', community)
driver.close()

# %%
# create an environment component
with driver.session() as session:
    environmentComponent = riopy.create_environment_component(
        tx = session,
        currentKnowledgeSpaceName = currentKnowledgeSpaceName,
        currentCollaborationName = currentCollaborationName,
        environmentComponentName = 'Test Environment Component',
        status = 'ACTIVE',
        description = 'Test Description',
        propertyLabels = ['Test 1', 'Test 2', 'Test 3'],
        point = [1, 2, 3]
    )
print('The identity of the created environment component is :', environmentComponent)
driver.close()

# %%
# delete a node
with driver.session() as session:
    riopy.delete_node(session, 189)
driver.close()

# %%
# get labels of node
with driver.session() as session:
    labels = riopy.get_labels_node(session, 188)
driver.close()
labels

# %%
# get names of properties of node
with driver.session() as session:
    keys = riopy.get_properties_names_node(session, 188)
driver.close()
keys

# %%
# get properties of node
with driver.session() as session:
    properties = riopy.get_properties_node(session, 188)
driver.close()
properties

# %%
# get specific property of node
with driver.session() as session:
    propertyValue = riopy.get_property_node(session, 188, 'property_name')
driver.close()
propertyValue

# %%
# get all nodes' names
with driver.session() as session:
    nodesNames = riopy.get_all_nodes_names(session)
driver.close()
nodesNames

# %%
# find a node by it's name
with driver.session() as session:
    nodes = riopy.find_node_by_name(session, "Test Community")
driver.close()
nodes

# %% [markdown]
# ## 4. Test functions for edge

# %%
# get infomation of edge
with driver.session() as session:
    info = riopy.get_info_edge(session, 252)
driver.close()
info

# %%
# get properties of edge
with driver.session() as session:
    properties = riopy.get_properties_edge(session, 53)
driver.close()
properties

# %%
# get names of properties of edge
with driver.session() as session:
    keys = riopy.get_properties_names_edge(session, 53)
driver.close()
keys

# %%
# get specific property of edge
with driver.session() as session:
    propertyValue = riopy.get_property_edge(session, 53, 'property_meta_ns')
driver.close()
propertyValue

# %%
# create an edge
with driver.session() as session:
    edge = riopy.create_edge(
        tx = session,
        currentKnowledgeSpaceName = currentKnowledgeSpaceName,
        currentCollaborationName = currentCollaborationName,
        start = 181,
        end = 182,
        edgeType = 'supports',
        properties = {'property_coverage': 12}
    )
driver.close()
print('The identity of the created edge is :', edge)

# %%
# delete an edge
with driver.session() as session:
    riopy.delete_edge(session, 253)
driver.close()
